# %% [markdown]
# ##**1. Importing dataset and pandas**

# %%
# !git clone https://github.com/AshishJangra27/datasets

import pandas
df = pandas.read_csv('datasets/Gaana/songs.csv')
from tqdm import tqdm #To track progress of a code
# Out:
# fatal: destination path 'datasets' already exists and is not an empty directory.

# %% [markdown]
# ##**2. Exploring Dataset**

# %%
df.head() #Gives top 5 results of the dataset
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# 3          /yeh-na-thi-hamari-qismat-2     Urdu
# 4           /hazaron-khwahishen-aisi-1     Urdu

# %%
df #Gives entire dataset
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# 41350                   Kishore Kumar
# 41351                    Feroza Begum
# 41352  Sandhya Mukherjee|Hemant Kumar
# 41353                Ajoy Chakrabarty
# 41354                     Asha Bhosle
#
#                                                singer_id duration  \
# 0           /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1           /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                                /artist/jagjeet-singh-1    03:41
# 3                                   /artist/chitra-singh    04:26
# 4                                /artist/jagjeet-singh-1    05:39
# ...                                                  ...      ...
# 41350                              /artist/kishore-kumar    03:23
# 41351                               /artist/feroza-begum    03:56
# 41352  /artist/sandhya-mukherjee|/artist/hemanta-mukh...    07:36
# 41353                           /artist/ajoy-chakrabarty    04:29
# 41354                              /artist/asha-bhosle-1    03:22
#
#                                                     link language
# 0                                   /dil-e-nadan-tujhe-3     Urdu
# 1                    /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                                         /unke-dekhe-se     Urdu
# 3                            /yeh-na-thi-hamari-qismat-2     Urdu
# 4                             /hazaron-khwahishen-aisi-1     Urdu
# ...                                                  ...      ...
# 41350  /chaaridike-paaper-andhar-manush-janam-diye-bidhi  Bengali
# 41351                                 /ei-kigo-sesh-daan  Bengali
# 41352                                      /ei-je-bangla  Bengali
# 41353                              /jatone-hridaye-rekho  Bengali
# 41354                           /tomar-je-oi-haater-mala  Bengali
#
# [41355 rows x 6 columns]

# %% [markdown]
# **2.1 : Print all column names**

# %%
for i in df.columns:
  print(i)
# Out:
# name
# singer
# singer_id
# duration
# link
# language

# %% [markdown]
# **2.1 : To check if any values are null.
# The null values will come as true and non null values will be displayed as False.**

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# **2.3 : To drop null values (if any)**

# %%
df.dropna()
#We can also fill null values with some values
#df.fillna(0)
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# 41350                   Kishore Kumar
# 41351                    Feroza Begum
# 41352  Sandhya Mukherjee|Hemant Kumar
# 41353                Ajoy Chakrabarty
# 41354                     Asha Bhosle
#
#                                                singer_id duration  \
# 0           /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1           /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                                /artist/jagjeet-singh-1    03:41
# 3                                   /artist/chitra-singh    04:26
# 4                                /artist/jagjeet-singh-1    05:39
# ...                                                  ...      ...
# 41350                              /artist/kishore-kumar    03:23
# 41351                               /artist/feroza-begum    03:56
# 41352  /artist/sandhya-mukherjee|/artist/hemanta-mukh...    07:36
# 41353                           /artist/ajoy-chakrabarty    04:29
# 41354                              /artist/asha-bhosle-1    03:22
#
#                                                     link language
# 0                                   /dil-e-nadan-tujhe-3     Urdu
# 1                    /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                                         /unke-dekhe-se     Urdu
# 3                            /yeh-na-thi-hamari-qismat-2     Urdu
# 4                             /hazaron-khwahishen-aisi-1     Urdu
# ...                                                  ...      ...
# 41350  /chaaridike-paaper-andhar-manush-janam-diye-bidhi  Bengali
# 41351                                 /ei-kigo-sesh-daan  Bengali
# 41352                                      /ei-je-bangla  Bengali
# 41353                              /jatone-hridaye-rekho  Bengali
# 41354                           /tomar-je-oi-haater-mala  Bengali
#
# [41355 rows x 6 columns]

# %% [markdown]
# **2.4 : Identifying rows with 'na' values and removing them from database by referring the index**

# %%
df[df['singer_id'] == 'na']
# Out:
# Empty DataFrame
# Columns: [name, singer, singer_id, duration, link, language]
# Index: []

# %%
#Deleting this index 36814 from the dataframe

df.drop(index=[36814], axis=0, inplace = True)

# %% [markdown]
# ##**3. Cleaning duration**
# Currently in format hh:mm:ss, we want to convert this into a standard format (Seconds) which can be incorporated better for our analysis

# %%
duration = list((df['duration'].values))
type(duration)
# Out:
# list

# %%
Std_duration=[]
for i in df['duration']:
  if len(i.split(':'))==2:
    mins = int(i.split(':')[0])
    secs = int(i.split(':')[1])
    Std_duration.append(mins*60+secs)
  else:
    hrs = int(i.split(':')[0])
    mins = int(i.split(':')[1])
    secs = int(i.split(':')[2])
    Std_duration.append(hrs*60*60+mins*60+secs)

print(type(Std_duration)) #Checking the type of our new duration
print(len(Std_duration)) #Checking the number of rows in our new duration
print(Std_duration) #Printing the list std_duration

df['Std_duration']=Std_duration #Adding this list as a new column in our dataframe
df.head()
# Out:
# <class 'list'>
# 41354
# [300, 386, 221, 266, 339, 479, 288, 321, 189, 264, 303, 240, 283, 339, 449, 228, 204, 219, 322, 359, 381, 271, 263, 156, 289, 280, 458, 403, 442, 357, 217, 301, 216, 228, 291, 196, 302, 343, 199, 264, 155, 288, 354, 196, 212, 186, 155, 241, 307, 197, 295, 1106, 84, 329, 276, 199, 391, 302, 225, 314, 256, 228, 309, 439, 238, 341, 245, 442, 219, 442, 268, 334, 279, 363, 261, 196, 326, 240, 226, 292, 300, 249, 257, 284, 206, 1582, 218, 281, 248, 382, 372, 192, 249, 289, 246, 464, 301, 207, 240, 196, 289, 195, 225, 198, 392, 321, 375, 381, 219, 200, 345, 1733, 384, 182, 336, 379, 354, 265, 196, 358, 189, 266, 276, 333, 186, 241, 189, 195, 261, 277, 198, 212, 178, 339, 395, 231, 216, 1249, 324, 405, 1143, 258, 398, 339, 258, 1641, 199, 262, 272, 348, 421, 424, 192, 791, 352, 1109, 719, 366, 355, 196, 2285, 388, 326, 758, 273, 247, 199, 361, 1760, 1653, 206, 263, 374, 185, 241, 336, 331, 267, 199, 294, 201, 208, 202, 267, 864, 182, 527, 291, 328, 198, 391, 379, 257, 376, 222, 258, 763, 319, 312, 1835, 360, 374, 277, 278, 697, 242, 281, 183, 244, 311, 197, 231, 404, 204, 214, 1199, 182, 328, 750, 504, 302, 249, 283, 273, 302, 188, 863, 198, 346, 466, 694, 353, 207, 272, 374, 845, 420, 200, 241, 211, 1163, 194, 385, 678, 203, 212, 287, 208, 585, 208, 408, 651, 416, 401, 216, 242, 410, 185, 379, 322, 204, 180, 201, 314, 312, 479, 328, 435, 412, 365, 1472, 1034, 262, 362, 168, 462, 355, 352, 199, 342, 182, 237, 204, 883, 278, 278, 181, 225, 206, 374, 401, 1188, 324, 388, 290, 206, 428, 454, 273, 1811, 201, 352, 621, 175, 194, 1017, 303, 3234, 1779, 1715, 521, 318, 175, 320, 297, 379, 416, 242, 575, 160, 297, 485, 455, 266, 355, 251, 186, 382, 261, 426, 204, 172, 302, 113, 285, 235, 294, 405, 383, 240, 212, 925, 620, 536, 439, 600, 180, 336, 427, 584, 201, 245, 300, 252, 540, 301, 736, 293, 404, 407, 263, 914, 203, 198, 1531, 419, 179, 212, 173, 295, 374, 197, 586, 828, 485, 255, 201, 822, 151, 391, 506, 1494, 402, 206, 368, 394, 204, 313, 300, 280, 537, 204, 184, 176, 347, 201, 181, 184, 209, 331, 337, 329, 208, 351, 386, 206, 325, 345, 413, 241, 268, 184, 308, 217, 174, 647, 701, 534, 315, 191, 259, 539, 355, 194, 299, 284, 379, 346, 396, 192, 301, 655, 200, 328, 296, 755, 315, 195, 188, 185, 201, 362, 180, 183, 394, 464, 364, 363, 307, 860, 516, 190, 609, 182, 435, 209, 245, 288, 261, 192, 343, 257, 356, 492, 351, 1732, 306, 281, 1788, 384, 496, 586, 337, 254, 946, 290, 211, 251, 1553, 410, 174, 195, 178, 339, 184, 292, 235, 499, 973, 1138, 405, 847, 272, 120, 408, 193, 322, 302, 198, 188, 275, 435, 818, 187, 183, 482, 207, 237, 741, 404, 168, 363, 345, 380, 319, 159, 188, 181, 512, 163, 382, 159, 146, 205, 371, 301, 298, 183, 204, 361, 286, 534, 994, 320, 213, 901, 328, 279, 136, 331, 631, 400, 278, 491, 332, 258, 385, 206, 354, 259, 208, 393, 173, 186, 213, 187, 264, 348, 861, 1790, 317, 405, 455, 192, 297, 527, 323, 192, 259, 195, 383, 253, 422, 357, 384, 371, 943, 322, 255, 207, 281, 425, 195, 170, 428, 205, 170, 208, 3621, 304, 375, 292, 312, 267, 222, 892, 235, 98, 334, 168, 358, 335, 391, 543, 768, 218, 316, 333, 367, 434, 199, 349, 402, 399, 383, 368, 204, 445, 374, 350, 295, 380, 259, 372, 366, 667, 552, 371, 197, 1288, 322, 241, 296, 195, 693, 252, 194, 274, 174, 394, 798, 211, 320, 485, 195, 245, 655, 230, 394, 299, 879, 290, 490, 313, 312, 426, 405, 374, 380, 358, 818, 614, 382, 287, 219, 365, 197, 929, 427, 774, 337, 228, 253, 393, 307, 196, 365, 199, 334, 183, 221, 582, 262, 325, 479, 654, 376, 186, 326, 223, 274, 319, 514, 207, 525, 209, 295, 242, 420, 808, 260, 214, 294, 384, 361, 263, 292, 339, 238, 401, 569, 643, 416, 381, 364, 895, 262, 255, 552, 802, 886, 20, 283, 230, 194, 217, 303, 281, 491, 748, 346, 364, 430, 312, 624, 193, 227, 384, 999, 254, 626, 822, 314, 592, 382, 31, 562, 299, 283, 273, 405, 244, 284, 220, 792, 702, 214, 342, 280, 298, 307, 311, 206, 186, 227, 868, 221, 248, 613, 304, 214, 186, 342, 469, 473, 1818, 304, 251, 277, 616, 302, 426, 312, 348, 240, 495, 267, 252, 185, 234, 257, 276, 334, 1406, 3 ...
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language  Std_duration
# 0                 /dil-e-nadan-tujhe-3     Urdu           300
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu           386
# 2                       /unke-dekhe-se     Urdu           221
# 3          /yeh-na-thi-hamari-qismat-2     Urdu           266
# 4           /hazaron-khwahishen-aisi-1     Urdu           339

# %% [markdown]
# ##**4. Cleaning Singers/ Singer_id**
#
# *   Removing the pipe operator ('|') and the repetitive string '/artist/'
# *   Inserting a comma between the singers in case of duets

# %%
df['singer'][0]
# Out:
# 'Chitra Singh|Jagjit Singh'

# %%
df['singer_id'] = [i.replace('/artist/','').replace('|',',') for i in df['singer_id']]
df['singer'] = [i.replace('|',',') for i in df['singer']]
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh,Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh,Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                       singer_id duration                                 link  \
# 0  chitra-singh,jagjeet-singh-1    05:00                 /dil-e-nadan-tujhe-3
# 1  chitra-singh,jagjeet-singh-1    06:26  /agar-hum-kahen-aur-woh-muskura-den
# 2               jagjeet-singh-1    03:41                       /unke-dekhe-se
# 3                  chitra-singh    04:26          /yeh-na-thi-hamari-qismat-2
# 4               jagjeet-singh-1    05:39           /hazaron-khwahishen-aisi-1
#
#   language  Std_duration
# 0     Urdu           300
# 1     Urdu           386
# 2     Urdu           221
# 3     Urdu           266
# 4     Urdu           339

# %% [markdown]
# ##**5. Analysing the data**

# %% [markdown]
# **5.1 : Finding number of songs in each language**

# %%
for i in df['language'].unique():
  n = 0
  for j in df['language']:
    if j == i:
      n += 1
  print(i, n)
# Out:
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4995
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %% [markdown]
# **5.2 : Finding number of songs in each language using sub-dataframe**

# %%
#Understanding what we require using sub-dataframe

df['language'] == 'Urdu' #This gives entire dataframe and values in True/ False
df[df['language'] == 'Urdu'] #This gives the sub-dataframe with Urdu as language
len(df[df['language'] == 'Urdu']) #This gives the count of such cases

print('Urdu', len(df[df['language'] == 'Urdu']))

for i in df['language'].unique():
  print(i, len(df[df['language'] == i]))
# Out:
# Urdu 3116
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4995
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %% [markdown]
# **5.3 : Finding the lengthiest song**

# %%
df['Std_duration'].max()


df[df['Std_duration'] == df['Std_duration'].max()]
# Out:
#              name          singer       singer_id  duration         link  \
# 16093  Haye Tumba  Dilshad Akhtar  dilshad-akhtar  07:08:00  /haye-tumba
#
#       language  Std_duration
# 16093  Punjabi         25680

# %% [markdown]
# **5.4 : Top 5 songs with maximum duration**

# %%
df.sort_values(by = 'Std_duration', ascending = False).head()
# Out:
#                                name          singer       singer_id  duration  \
# 16093                    Haye Tumba  Dilshad Akhtar  dilshad-akhtar  07:08:00
# 16352                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar  06:52:00
# 15000                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar  06:52:00
# 15025          Kanu Atharu Bahoundi  Dilshad Akhtar  dilshad-akhtar  06:04:00
# 14624  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  dilshad-akhtar  06:03:00
#
#                                   link language  Std_duration
# 16093                      /haye-tumba  Punjabi         25680
# 16352                  /bum-bum-lahiri  Punjabi         24720
# 15000                /bum-bum-lahiri-1  Punjabi         24720
# 15025            /kanu-atharu-bahoundi  Punjabi         21840
# 14624  /desi-bandri-vilayati-cheekan-1  Punjabi         21780

# %% [markdown]
# **5.5 : Find number of songs with duration greater than 30 minutes**

# %%
#Method-1
n = 0
for i in df['Std_duration']:
  if i > 30*60:
    n += 1

print(n)
# Out:
# 243

# %%
#Method-2

len(df[df['Std_duration'] > 30*60])
# Out:
# 243

# %% [markdown]
# **5.6 : Finding Average Duration of all songs in the dataset**

# %%
float(str(sum(df['Std_duration'])/len(df['Std_duration']))[0:6])
# Out:
# 312.56

# %% [markdown]
# **5.7 : Finding Average Duration of songs in Urdu**

# %%
int(df[df['language'] == 'Urdu']['Std_duration'].mean())
# Out:
# 410

# %% [markdown]
# **5.8 : Finding Average Duration of songs in each language**

# %%
df.groupby(by = 'language')['Std_duration'].mean().sort_values(ascending = False).round(2)
# Out:
# language
# Punjabi       448.32
# Urdu          410.69
# Bhojpuri      364.07
# Haryanvi      320.00
# Telugu        314.23
# Hindi         310.10
# Old           310.10
# Rajasthani    291.04
# Marathi       282.76
# Tamil         273.26
# Gujarati      271.63
# Odia          257.63
# Bengali       255.18
# Kannada       252.73
# Malayalam     242.61
# Assamese      228.33
# Name: Std_duration, dtype: float64

# %% [markdown]
# **5.9 : Finding Lengthiest Song duration of Each Language**

# %%
df.groupby(by = 'language')['Std_duration'].max()
# Out:
# language
# Assamese       2586
# Bengali        3186
# Bhojpuri       3660
# Gujarati       3562
# Haryanvi       3588
# Hindi          3876
# Kannada        4084
# Malayalam      1556
# Marathi        4033
# Odia           3273
# Old            3876
# Punjabi       25680
# Rajasthani     1773
# Tamil          4545
# Telugu        10409
# Urdu           3621
# Name: Std_duration, dtype: int64

# %% [markdown]
# **5.10 : No. of songs in Urdu**

# %%
m = 0

for i in df['language']:
  if i=='Urdu':
    m += 1

print(m)
# Out:
# 3116

# %% [markdown]
# **5.11 : Finding the song names whose duration is greater than 30 mins and language is Urdu**

# %%
from itertools import zip_longest

for i,j,k in zip_longest(df['Std_duration'],df['language'],df['name']):
  if i>30*60 and j == 'Urdu':
    print(k,':',i, 'Seconds')
# Out:
# Kahne Deti Nahin Kuchh Mujh Se Mohabbat Teri : 2285 Seconds
# Shikwa-Jawab-e-Shikwa, Pt. 1 : 1835 Seconds
# Shikwa-Jawab-E-Shikwa, Pt. 2 : 1811 Seconds
# Namaz : 3234 Seconds
# Aziz Mian - Ae ri Main to Prem Deewani : 3621 Seconds
# Tere Ishq Nachaya Kar : 1818 Seconds
# Yeh Paisa Kya Karega : 3595 Seconds
# Mitti Ki Moorat, Pt. 1 : 1820 Seconds
# Heer : 1834 Seconds
# Pathar Pooje : 3503 Seconds
# Mariz-E-Mohabbat Unhi Ka : 1801 Seconds
# Es Tere Sar Ki Qasam - Part 1 : 1861 Seconds
# Sultan Bahu : 1817 Seconds
# Sanson Ki Mala : 1805 Seconds
# Mitti Ki Moorat, Pt. 2 : 1814 Seconds
# Tha Bhi Main Hoon Bhi Main : 3525 Seconds
# Main Kiya Janoon Ram, Pt. 1 : 1819 Seconds
# Bohat Kathan Hai : 3609 Seconds
# Es Tere Sar Ki Qasam - Part 2 : 1834 Seconds
# Main Kiya Janoon Ram, Pt. 2 : 1806 Seconds
# Shahbaz Qalandar : 3475 Seconds
# Anwar Maqsood Show : 3475 Seconds
# Raag Hameer Part 1 : 1835 Seconds
# Raag Lalit : 1802 Seconds
# Ya Mohd Men Tere Naam : 1810 Seconds
# Raag Kalavati : 1830 Seconds
# Dilawar Figaar - Shaakar Ka Qahet & Others : 3608 Seconds

# %% [markdown]
# **5.12 : Top 5 songs in Urdu based on duration**

# %%
df[df['language']=='Urdu'].sort_values(by = 'Std_duration', ascending=False).head()['name']
# Out:
# 588         Aziz Mian - Ae ri Main to Prem Deewani
# 1441                              Bohat Kathan Hai
# 3013    Dilawar Figaar - Shaakar Ka Qahet & Others
# 818                           Yeh Paisa Kya Karega
# 1400                    Tha Bhi Main Hoon Bhi Main
# Name: name, dtype: object

# %% [markdown]
# **5.13 : Average duration for Urdu songs**

# %%
int(df[df['language']=='Urdu']['Std_duration'].mean())
# Out:
# 410

# %% [markdown]
# **5.14.1 : Average duration of songs for each language**

# %%
#Method-1

for i in df['language'].unique():
  print( i, int(df[df['language']==i]['Std_duration'].mean()))
# Out:
# Urdu 410
# Gujarati 271
# Tamil 273
# Kannada 252
# Rajasthani 291
# Haryanvi 320
# Punjabi 448
# Hindi 310
# Old 310
# Malayalam 242
# Marathi 282
# Telugu 314
# Odia 257
# Bhojpuri 364
# Assamese 228
# Bengali 255

# %%
#Method-2

df.groupby(by= 'language')['Std_duration'].mean().round(2)
# Out:
# language
# Assamese      228.33
# Bengali       255.18
# Bhojpuri      364.07
# Gujarati      271.63
# Haryanvi      320.00
# Hindi         310.10
# Kannada       252.73
# Malayalam     242.61
# Marathi       282.76
# Odia          257.63
# Old           310.10
# Punjabi       448.32
# Rajasthani    291.04
# Tamil         273.26
# Telugu        314.23
# Urdu          410.69
# Name: Std_duration, dtype: float64

# %% [markdown]
# **5.14.2 : Average duration of songs for each language (Plot in pie chart)**

# %%
df.groupby(by= 'language')['Std_duration'].mean().round(2).plot(kind='pie')
# Out:
# <Axes: ylabel='Std_duration'>

# %% [markdown]
# **5.15.1 : Finding Number of Songs in Each Language**

# %%
df.groupby(by='language').size().sort_values(ascending=False)
# Out:
# language
# Telugu        4995
# Hindi         4993
# Old           4993
# Marathi       4699
# Tamil         4677
# Punjabi       3818
# Kannada       3559
# Urdu          3116
# Gujarati      2115
# Bengali        958
# Odia           940
# Assamese       724
# Rajasthani     541
# Bhojpuri       519
# Malayalam      479
# Haryanvi       228
# dtype: int64

# %% [markdown]
# **5.15.2 : Finding Number of Songs in Each Language (Plot in Bar Graph)**

# %%
df.groupby(by='language').size().sort_values(ascending=False).plot(kind='bar', title = 'Number of Songs in Each Language')
# Out:
# <Axes: title={'center': 'Number of Songs in Each Language'}, xlabel='language'>

# %%
#df.groupby(by='singer_id').size().sort_values(ascending=False).head(10).plot(kind='barh')

# %% [markdown]
# **5.16 : Singers with maximum number of songs**

# %%
df.groupby('singer_id').count()['name'].sort_values(ascending = False).head(10)
# Out:
# singer_id
# lata-mangeshkar                      1410
# asha-bhosle-1                        1274
# kishore-kumar                        1213
# mohammad-rafi                        1201
# s-p-balasubrahamanyam                1168
# p-suseela-2                          1019
# s-janaki                              730
# s-p-balasubrahamanyam,p-suseela-2     682
# noor-jehan                            490
# s-p-balasubrahamanyam,s-janaki        455
# Name: name, dtype: int64

# %% [markdown]
# There is an issue with above output. S.P. balasubrahamanyam is counted in multiple cases - in solo cases as well as duet with different people. We will fix this in 5.19

# %% [markdown]
# **5.17 : Finding unique number of singers**

# %%
#We will first find out the list of unique singers only

singers_c = []

for i in df['singer_id']:
  singers_c += i.split(',')

singers_c = list(set(singers_c))

print(singers_c)
print(len(singers_c))
# Out:
# ['akash-group', 'gauri-bapat', 'baby-kum-kum', 'bharati-das-1', 'salim', 'prayag-raj', 'p-b-sreenivas', 'mohd-saddiq-ismail', 'bhalchandra-pendarkar', 'valee', 'mamta-sing', 's-p-sailaja', 'digen-mahanta', 'sudhir-phadle-26', 'bhairav-prasad-kathak', 'baldev-singh-fatehwala-4', 'b-jayamma-29', 'r-gauri-aiyyar-1', 'swati-pandit', 'meenu-chadha', 'ghanshyam-vaswani', 'mohan', 'bs-sasirekha-1', 'sameer-date', 'bhai-nazar-singh-dehradun-wale-19', 't-r-raghunath-1', 'vasumati-donde', 'masum', 'om-rahi', 'jagjeet-kaur', 'uma-ramanan-1', 't-s-balaiah-1', 'saleem-shahzad', 'chitra-chorus-2', 'inayat-ali', 'rahat-fateh-ali-khan', 'raghunan-panshikar-4', 'srinivas', 'jaswant-singh-sandila-13', 'lranjali', 'kamaljeet-kaur-neeru-3', 'v-bandaru', 'b-souri', 'madhumati-goswami', 'purna-das-baul', 'pramodini-desai', 'murli-meghani', 'raj-bala', 'shammi-kapoor', 'michael-foot', 'zubaida-khanum', 'rasik-pathak', 'jyotsna-mohile', 'ruby-singha', 'gopi-patnaik', 'km-adyasa-roy', 'swapan-chakraborty', 'baby-guruprit-kaur', 'kyum-ahmed', 'gurmeet-bawa', 'shekh-jainu-chand', 'nagendrappa', 'banikantha-nimai-charan-harichandan', 'ashwini-somasundaram', 'swarna', 'muka-muthu-6', 'feroz-khan', 'kalpana-shirur', 'harshika', 'vivek-sarathy', 'd-pen-baruah', 't-r-narasimharaju', 'shahaji-kale', 'chandan-dass', 'others', 'mjaved', 'koundamani', 'swagatalakshmi-dasgupta', 'ambilikuttan', 'rk-shriram-kumar-7', 'ratannagar', 'robert-uhlmarash', 'kamala-unhavne', 'gulab-singh', 'kannur-rajan', 'ms-rama-rao-40', 'bhupen-hazarika', 'mahananda-majindar-baruah', 'monika', 'shashikala', 'hussain-bukhsh-khan', 'sarvjeet-sharma-4', 'm-ashok-1', 'kumar-sonik', 'bhanti-barua', 'sunil-ganguly', 'arun-jangale', 'masood-malik', 'bhai-surinder-singh', 'tripti-chhaya', 'shamim', 'farid-ayaz-qawwal', 'prof-ram-shevalkar-6', 'rajanala', 'parti', 'ranjna-joglekar', 'medha-bhosle', 'mina-patel', 'vijaya-mazumder-2', 'suresh-shinde', 'girish-varadpe-34', 'shakuntala-kambli', 'purabi-mukherjee', 'kunda-wagalikar', 'badari-prasad', 'girish-varadpe-36', 'nirmali-das', 'srikanth', 'a-p-nagarajan-5', 'p-suri-babu-13', 'arshi-hyderabadi', 'sushma-shrestha', 'punjabi-bhangra', 'shobha-purohitanand-kuar-7', 'manju-noorpuri', 'u-thiyagarajan-1', 'mr-vijaya-11', 'dominique-cerejo', 'arpana-chaudhary-2', 'sadhna-sargam-1', 'p-susheela-and-chorus-1', 'kadambari', 'krishnachandran', 'sunitha-chandrakumar', 'not-applicable', 'savita-sathi-1', 'mj-sebastian', 'raj-kumar-bharathi', 'maipala-vijayalakshmi', 'nathalal-chorasia', 'j-p-chandrababu', 'ustad-amanat-ali-khan', 'manubhai-babariya-1', 'indhra', 'rudrappa', 'sp-ponnuswamy-1', 'gvenugopal', 'devadas', 'jagannath', 'mithun-chakraborty', 'ks-vasudevan-13', 'ramdas-patil', 'bhai-tarlochan-singh-ji', 'manohar-ovlekar', 'sohan-lal', 'ajay-wadyer', 'm-l-vasanthakumari-1', 'mrinalini-dutta-chowdhury-1', 'nandi-duggal', 'dayal-pawar', 'arun-das', 'janaki-iyer', 'fazal-hussain', 'anitha-reddy', 'srikanta-das', 'dr-seerkazhi', 'justin-prabhakaran', 'kishori-amonkar', 'preeti-uttam', 'bhanumathi-ramakrishna', 'harishankar', 'indirabai-khadilkar', 'sibaprashad-nath', 'kamal-haasan', 'satyavathi', 'robin-mukherjee', 'smt-davender-singh', 'keshav-badge', 'antara-chwdhury', 'rajan-nagendra-1', 'lakshmipathy', 'anima-chowdhury-2', 'pooran-chand', 'ramya-vasista', 'fritz-manuel', 'major-sunderarajan', 'ustad-salamat-ali-khan', 'm-kapoor-1', 'inder-kaur', 'spsailaja', 'naseeruddin-shah', 'arzoo-bano', 'mohammad-ali-shyhaki-1', 'roshan-e-zafar', 'sagar-sen', 'iru-saika-2', 'usha-kaur-2', 'mriaz', 'runa-laila', 'gopal-bohra', 'durga-jasraj', 'balu', 'anwar', 'shanta-apte', 'parshuram-patil', 'calcutta-youth-choir', 'laxmi-prasad-2', 'jaswin-jassi', 'shankar-shambhu-qawwal-81', 'gurmit-randhawa', 'dr-rohini-mohan', 's-v-ponnusamy', 'afshan-ahmed', 'sadguru-sant-keshavadas', 'bashir-ali-mahi', 'prof-satnam-singh-sethi-1', 'jayalalithaa-5', 'rekha-bhardwaj', 'arundhuti', 'assam-singers-with-percussion-from-kohima', 'om-prakash-yadav', 'shravan-yashwante', 'pra ...
# 4527
# 4527

# %% [markdown]
# **5.18 : Finding number of songs sung by each singer**

# %%
lst = []

for i in tqdm(singers_c):
  f = 0
  for j in df['singer_id']:
    if i in j:
      f += 1

  lst.append([i,f])

lst

# %% [markdown]
# **5.19 : Singers with maximum number of songs (by restructuring the dataset)**

# %%
songs = pandas.DataFrame(lst, columns = ['singer_id','songs'])
songs.head()
songs.sort_values(by = 'songs', ascending = False).head(10)
# Out:
#                   singer_id  songs
# 3280  s-p-balasubrahamanyam   3663
# 223                   kumar   3576
# 866             p-suseela-2   3212
# 2423        lata-mangeshkar   3056
# 2310          asha-bhosle-1   2715
# 2060          kishore-kumar   2401
# 2919                 janaki   2218
# 3157               s-janaki   2206
# 2276          mohammad-rafi   2138
# 2265                 chorus   1179
